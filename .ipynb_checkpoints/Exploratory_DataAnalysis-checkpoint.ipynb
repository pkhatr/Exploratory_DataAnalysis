# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Import required libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly 

# %matplotlib inline

# %%
# Setting up default font size values for charts
# We might change the font size manually for some charts if required
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=12)    # fontsize of the tick labels
plt.rc('ytick', labelsize=12)    # fontsize of the tick labels
plt.rc('legend', fontsize=14)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

# %% [markdown]
# ## Read File and Perfrom basic data profiling

# %%
# Read CSV file
df = pd.read_csv('bestsellers with categories.csv')

# %%
# Check the first 5 rows
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# Show Column names
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
# Find the shape of data
shape = df.shape
print('Rows: ' + str(shape[0]) + '\nCols: ' + str(shape[1]))
# Out:
# Rows: 550
# Cols: 7

# %%
# Summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
# Some statistical information about dataset
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
# Counting for null
df.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
# Counting Number of unique values for each column
df.nunique()
# Out:
# Name           351
# Author         248
# User Rating     14
# Reviews        346
# Price           40
# Year            11
# Genre            2
# dtype: int64

# %%
# Pairwise plot for numerical columns
sns.pairplot(df)

# %% [markdown]
# ## Analysis for Books

# %% [markdown]
# ### Finding out how many times each book became the best seller

# %%
# Find out how many times book became best seller
book_gs = df.groupby('Name')['Year'].count()
book_gs.sort_values(ascending=False, inplace=True)
book_gs
# Out:
# Name
# Publication Manual of the American Psychological Association, 6th Edition                       10
# StrengthsFinder 2.0                                                                              9
# Oh, the Places You'll Go!                                                                        8
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change                     7
# The Very Hungry Caterpillar                                                                      7
#                                                                                                 ..
# Sycamore Row (Jake Brigance)                                                                     1
# The 17 Day Diet: A Doctor's Plan Designed for Rapid Results                                      1
# The 4 Hour Body: An Uncommon Guide to Rapid Fat Loss, Incredible Sex and Becoming Superhuman     1
# The 5000 Year Leap                                                                               1
# 10-Day Green Smoothie Cleanse                                                                    1
# Name: Year, Length: 351, dtype: int64

# %%
# Filtering out for books that became best seller more than once
book_g1 = book_gs[book_gs > 1]
print('Total number of books listed more than once as best seller is', len(book_g1))
print('And')
print('The book that listed for most number of year is', book_gs.index[0], 
      'with listed as being top seller', book_gs.values[0], 'times.')
# Out:
# Total number of books listed more than once as best seller is 96
# And
# The book that listed for most number of year is Publication Manual of the American Psychological Association, 6th Edition with listed as being top seller 10 times.

# %% [markdown]
# ## Adding New Column dataframe to show number of years listed as best seller

# %%
# Adding column using apply and lambda function
df['Number_Years'] = df.apply(lambda x: book_gs[x['Name']], axis=1)
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Number_Years
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# ## Creating another Dataframe dropping duplicate record for books, keeping first record only

# %%
df_unique = df.drop_duplicates(subset=['Name']).copy()
print('Total Rows (Original):', df.shape[0])
print('Total Rows (After dropping duplicates):', df_unique.shape[0])
# Out:
# Total Rows (Original): 550
# Total Rows (After dropping duplicates): 351

# %% [markdown]
# ### Note
# Going Forward we will use either df or df_unique based on the analysis

# %% [markdown]
# ## Correlation

# %%
# Finding correlation among the columns original data
corr = df.drop(columns=['Number_Years']).corr()
corr.style.background_gradient(cmap='Blues').set_precision(3)
# Out:
# <style  type="text/css" >
# #T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col0,#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col1,#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col2,#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col1{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col2{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col3{
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col0{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col2{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col3{
#             background-color:  #a3cce3;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col0,#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col1,#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col3,#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col0{
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col1{
#             background-color:  #aacfe5;
#             color:  #000000;
#         }</style><table id="T_b6f30ed4_eab8_11eb_af2b_f018982d605b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >User Rating</th>        <th class="col_heading level0 col1" >Reviews</th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6f30ed4_eab8_11eb_af2b_f018982d605blevel0_row0" class="row_heading level0 row0" >User Rating</th>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col1" class="data row0 col1" >-0.002</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col2" class="data row0 col2" >-0.133</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow0_col3" class="data row0 col3" >0.242</td>
#             </tr>
#             <tr>
#                         <th id="T_b6f30ed4_eab8_11eb_af2b_f018982d605blevel0_row1" class="row_heading level0 row1" >Reviews</th>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col0" class="data row1 col0" >-0.002</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col2" class="data row1 col2" >-0.109</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow1_col3" class="data row1 col3" >0.264</td>
#             </tr>
#             <tr>
#                         <th id="T_b6f30ed4_eab8_11eb_af2b_f018982d605blevel0_row2" class="row_heading level0 row2" >Price</th>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col0" class="data row2 col0" >-0.133</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col1" class="data row2 col1" >-0.109</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow2_col3" class="data row2 col3" >-0.154</td>
#             </tr>
#             <tr>
#                         <th id="T_b6f30ed4_eab8_11eb_af2b_f018982d605blevel0_row3" class="row_heading level0 row3" >Year</th>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col0" class="data row3 col0" >0.242</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col1" class="data row3 col1" >0.264</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col2" class="data row3 col2" >-0.154</td>
#                         <td id="T_b6f30ed4_eab8_11eb_af2b_f018982d605brow3_col3" class="data row3 col3" >1.000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Alternative way to generate correlation

# %% [markdown]
# ### Note
# The best thing about python is there are many ways to do the same thing

# %%
# Alternative way to create a correlation plot using seaborn
# Original data and unique books data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
sns.heatmap(corr, vmin=-1, vmax=1, cmap='Blues', annot=True, fmt='.3f', ax=ax1)
ax1.set_title('Original Data')
sns.heatmap(df_unique.drop(columns=['Year', 'Number_Years']).corr(), vmin=-1, vmax=1, cmap='Blues', annot=True, fmt='.3f', ax=ax2)
ax2.set_title('After Dropping Duplicates')
# Out:
# Text(0.5, 1.0, 'After Dropping Duplicates')

# %% [markdown]
# There is a slight change in correaltion after excluding duplicates, however, the correlation is between each variables.

# %% [markdown]
# ## Genre Analysis

# %% [markdown]
# ### Finding out the proportion of best selling books by Genre

# %%
# Best-selling book by Genre (for all years)
# Original data was used
genre_count = df['Genre'].value_counts()
genre_count
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %%
# Create pie chart for genre
plt.figure(figsize=(8, 8))
plt.pie(genre_count, labels=genre_count.index, autopct='%1.0f%%', 
       textprops={'fontsize': 16})
plt.title('Breakdown by Genre', fontsize=20)
plt.show()

# %% [markdown]
# ### Finding the distribution of rating, total reviews and price for each Genre

# %%
fig, ax_genre = plt.subplots(1, 3, figsize=(18, 6), sharey=False)
df_unique.boxplot(by='Genre', column=['User Rating', 'Reviews', 'Price'], ax=ax_genre, fontsize=14)
for i in ax_genre:
    i.set_title(i.get_title(), fontsize=16)
    i.set_xlabel('')
fig.suptitle('Distribution Based on Genre', fontsize=20)
plt.figure()
# Out:
# /Users/pkhatri/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py:380: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   ax = boxplot(

# %% [markdown]
# ## Analysis of Author

# %% [markdown]
# ### Creating dataframe containing author's summary

# %%
# Calculating total books, total reviews and average book price for each author
author = df_unique.groupby('Author').agg(Total_Books=pd.NamedAgg(column='Name', aggfunc='count'), 
                                 Total_Reviews=pd.NamedAgg(column='Reviews', aggfunc='sum'), 
                                 Avg_Book_Price=pd.NamedAgg(column='Price', aggfunc='mean')).reset_index()
author.sort_values(by=['Total_Books', 'Total_Reviews'], ascending=False, inplace=True, ignore_index=True)
author
# Out:
#                 Author  Total_Books  Total_Reviews  Avg_Book_Price
# 0          Jeff Kinney           12          67482        9.250000
# 1         Rick Riordan           10          39541       10.200000
# 2      Stephenie Meyer            7          44058       19.857143
# 3         J.K. Rowling            6          70535       20.166667
# 4        Bill O'Reilly            6          54445       10.666667
# ..                 ...          ...            ...             ...
# 243         Mark Twain            1            491       14.000000
# 244   Larry Schweikart            1            460        2.000000
# 245        Jon Stewart            1            440       11.000000
# 246  Edward M. Kennedy            1            438       15.000000
# 247  Peter A. Lillback            1            408       20.000000
#
# [248 rows x 4 columns]

# %% [markdown]
# ### Finding out information about top 20 authors based on best seller

# %%
author.head(20).plot(x='Author', kind='bar')
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
axes = author.head(20).plot.bar(x='Author', subplots=True, figsize=(20,16), fontsize=14, legend=False)
for ax in axes:
    ax.set_title(ax.get_title(), fontsize=20)
    ax.set_ylabel('Count', fontsize=18)
axes[-1].set_xlabel(axes[-1].get_xlabel(), fontsize=18)
plt.show()

# %% [markdown]
# ## Rating Analysis

# %% [markdown]
# ### Finding out the distribution of rating

# %%
# Total count for each Rating and show it as dataframe
# Unique books data
rating_hist = df_unique['User Rating'].hist(bins=10, figsize=(10,6))
rating_hist.set_title('Distribution of Rating', fontsize=18)
rating_hist.set_xlabel('Rating', fontsize=14)
rating_hist.set_xlim(0, 5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# ### Finding out how the distribution of user rating looks for books listed multiple times and books listed just once as best seller

# %%
fig, axes = plt.subplots(figsize=(18,6))
sns.violinplot(x='Number_Years', y='User Rating', data=df_unique, ax=axes, inner=None)
sns.stripplot(x='Number_Years', y='User Rating', data=df_unique, ax=axes, color='k')
axes.set_title('User Rating vs Number of Years Listed', fontsize=20)
axes.set_xlabel('Number of Years Listed', fontsize=16)
axes.set_ylabel('Rating', fontsize=16)
plt.show()

# %% [markdown]
# ## Review Analysis

# %% [markdown]
# ### Performing similar analysis as Rating

# %% [markdown]
# ### Finding out the distribution of Reviews

# %%
# Unique books data
review_hist = df_unique['Reviews'].hist(bins=100, figsize=(10,6))
review_hist.set_title('Distribution of Reviews', fontsize=18)
review_hist.set_xlabel('Reviews', fontsize=14)
review_hist.set_xlim(0,100000)
reveiw_ticks = np.arange(0, 100001, 10000)
review_hist.set_xticks(major_ticks)
plt.show()

# %% [markdown]
# ### Finding out how the distribution of review looks for books listed multiple times and books listed just once as best seller

# %%
fig, axes = plt.subplots(figsize=(18,10))
sns.violinplot(x='Number_Years', y='Reviews', data=df_unique, ax=axes, inner=None)
sns.stripplot(x='Number_Years', y='Reviews', data=df_unique, ax=axes, color='k')
axes.set_title('Reviews vs Number of Years Listed', fontsize=20)
axes.set_xlabel('Number of Years Listed', fontsize=16)
axes.set_ylabel('Reviews', fontsize=16)
#axes.set_ylim(0, 100000)
plt.show()

# %% [markdown]
# ## Price Analysis

# %% [markdown]
# ### Finding out the distribution of Price

# %%
# Creating histogram using seaborn including kernel density estimate
fig, axes = plt.subplots(figsize=(10, 6))
sns.histplot(data=df_unique, x='Price', ax = axes, kde=True)
axes.set_title('Distribution of Price', fontsize=20)
axes.set_xlabel('Price', fontsize=16)
axes.set_ylabel('Count', fontsize=16)
plt.show()

# %% [markdown]
# Here, most book has price lower than 40. There are few expensive books

# %% [markdown]
# ### Lets find all the expensive books

# %%
df_unique[(df_unique['Price']>40)].sort_values(by='Price', ascending=False).reset_index(drop=True)
# Out:
#                                                 Name  \
# 0  Diagnostic and Statistical Manual of Mental Di...
# 1                       The Twilight Saga Collection
# 2                           Hamilton: The Revolution
# 3  The Book of Basketball: The NBA According to T...
# 4         Harry Potter Paperback Box Set (Books 1-7)
# 5  Publication Manual of the American Psychologic...
# 6                                           Watchmen
#
#                                Author  User Rating  Reviews  Price  Year  \
# 0    American Psychiatric Association          4.5     6679    105  2013
# 1                     Stephenie Meyer          4.7     3801     82  2009
# 2                  Lin-Manuel Miranda          4.9     5867     54  2016
# 3                        Bill Simmons          4.7      858     53  2009
# 4                       J. K. Rowling          4.8    13471     52  2016
# 5  American Psychological Association          4.5     8580     46  2009
# 6                          Alan Moore          4.8     3829     42  2009
#
#          Genre  Number_Years
# 0  Non Fiction             2
# 1      Fiction             1
# 2  Non Fiction             1
# 3  Non Fiction             1
# 4      Fiction             1
# 5  Non Fiction            10
# 6      Fiction             1

# %% [markdown]
# ## Year Analysis

# %% [markdown]
# ### Finding out total number of best selling books each year

# %%
df_year = df.groupby(['Year', 'Genre'])['Name'].count().unstack().fillna(0)
fig, ax_yr = plt.subplots(figsize=(12, 8))
df_year.plot(kind='bar', stacked=True, ax=ax_yr)
ax_yr.set_title('Total Best Selling Books Per YR')
ax_yr.set_ylim(0, 60)
ax_yr.legend(loc='best')
plt.show()
